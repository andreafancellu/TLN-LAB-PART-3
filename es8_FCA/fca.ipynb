# %% [markdown]
# # Esercizio 8 - Formal Concept Analysis (FCA)

# %% [markdown]
# Utilizzo della librearia *concepts* per la realizzazione di una ontologia in maniera automatica.

# %%
from concepts import Context

# %%
r = Context.fromfile('../data/concepts_data.csv', frmat='csv')
r.lattice.graphviz(view=True)

# %% [markdown]
# ### Esempi di utilizzo della libreria

# %%
# aspetto intensionale 
print(r.intension(['chicken']))
print(r.intension(['penguin']))
# aspetto estensionale
print(r.extension(['milk']))
print(r.extension(['eggs']))
# Out:
# ('feathers', 'eggs', 'airborne', 'backbone', 'breathes', 'domestic', 'catsize')
# ('feathers', 'eggs', 'aquatic', 'predator', 'backbone', 'breathes')
# ('deer', 'giraffe', 'leopard', 'lion', 'whale')
# ('chicken', 'octopus', 'penguin', 'snake')
